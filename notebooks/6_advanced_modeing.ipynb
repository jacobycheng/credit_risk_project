# %%
LGD = 0.5  # assume 50% loss
df_eval["EAD"] = X_test["LIMIT_BAL"].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 LGD = 0.5  # assume 50% loss
# ----> 2 df_eval["EAD"] = X_test["LIMIT_BAL"].values
#
# NameError: name 'X_test' is not defined

# %%
df_eval["expected_loss"] = (
    df_eval["log_prob"] * LGD * df_eval["EAD"]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 df_eval["expected_loss"] = (
# ----> 2     df_eval["log_prob"] * LGD * df_eval["EAD"]
#       3 )
#
# NameError: name 'df_eval' is not defined

# %%
df_eval.sort_values(by="expected_loss", ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_eval.sort_values(by="expected_loss", ascending=False).head(10)
#
# NameError: name 'df_eval' is not defined

# %%
df_eval["expected_loss"].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_eval["expected_loss"].describe()
#
# NameError: name 'df_eval' is not defined

# %%
df_eval["expected_loss"].hist(bins=30)
plt.title("Distribution of Expected Loss")
plt.show()
